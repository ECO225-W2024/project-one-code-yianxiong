# %% [markdown]
# <h1 align="center"> Exploring Venture Capital Dynamics: The Impact of Pre-Money Valuation and Other Factors on Startup Fundraising Success</h1>

# %% [markdown]
# ## Introduction
# **Background Information of the Research**
# Venture capital (VC) is a form of private equity investment where firms or funds provide capital to startups or small businesses with strong growth potential in exchange for equity, or partial ownership. This relationship is significant for startups since they often lacking access to capital markets, because VCs not only inject necessary funds but also offers business expertise, mentorship, and access to a wider network. VC investments are typically made in early-stage companies, aiming to cash out with a significant return through an event like an initial public offering (IPO) or sale (Zider, 1998). The dynamic between VCs and startups is fundamental, with VC acting as a crucial bridge for startups to scale operations, accelerate growth, and realize their market potential. This dynamic not only accelerates technological innovation and economic development but also contributes to job creation and competitive market dynamics.
#
# **Purpose of the Research**
# The investigation into "Exploring Venture Capital Dynamics: The Impact of Pre-Money Valuation and Other Factors on Startup Fundraising Success?" serves a various purpose, which rooted in both the operational strategies of startups and the broader economic implications. This research is aiming for presenting how do factors such as pre-money valuation influences the trajectory of startup fundraising development, and by exploring this relationship, stakeholders across the startup ecosystem can gain valuable insights into the mechanisms of startup growth, investment strategies, and the broader implications for innovation and economic development. From an economic perspective, factors like pre-money valuation and geographic location significantly impact startup fundraising success. This research explores how these variables shape capital flow within the startup ecosystem, influencing growth and expandability. By delving into these dynamics, we aim to provide insights that can guide stakeholders in developing targeted support and strategic interventions to bolster economic development and innovation.
#
# In the second part of the research, we explore the impact of regional disparities on early-stage funding, drawing on insights from Jun Chen and Michael Ewens (2021). They highlight that areas outside major capital clusters often face financing constraints, leading to missed investment opportunities for high-growth startups. This suggests a potential link between a startup's location and its funding success. Given these regional differences, it's crucial to investigate how geography influences funding dynamics to uncover patterns that could inform investment strategies and regional economic policies.
#
# **Data Source**
# The Crunchbase 2013 Snapshot dataset collaborated by Justinas Cirtautas offers an in-depth look into the expanding startup ecosystem. With annual VC investments surpassing $100 billion in the US alone, this dataset summarizes the vibrancy of the startup landscape, featuring a comprehensive array of data points covering from organizations and individuals to funding rounds, acquisitions, and IPOs. Comprising 11 interconnected tables that can be navigated through unique IDs, it provides a rich foundation for various analyses. Despite the absence of an extensive data quality review, this unique compilation remains an invaluable resource for insights up to December 2013, as confirmed by its exclusive availability and the recognition of its contribution by Crunchbase (Crunchbase, 2013).
#
# In the current version of this project, we will be focusing more onto the tables of *"funds.csv"* ，*"funding_rounds.csv"* and *"offices"*. More tables could be added along the way of research.
#
# **Main Variable of Interest: Pre-Money Valuation**
# In the course of our research, particularly through the analysis outlined in "Covariates and Their Correlation with the Outcome (Y)" *(Section 1.4)*, we have identified a likely positive correlation between the amount raised by startups and their pre-money valuation. This relationship suggests that the valuation of a startup before receiving external funding may significantly influence its fundraising success. Consequently, in this segment of our research, we will introduce **'pre_money_valuation'** as a new independent variable. Our focus will be to further explore the dynamics of this variable, examining how pre-money valuation impacts the financial outcomes for startups in the venture capital landscape. This investigation aims to provide a deeper understanding of the factors that contribute to effective fundraising and the role of valuation in attracting investment.

# %% [markdown]
# ## 1.1 Variable Explanation
# **Outcome(Y):**
# **'raised_amount_usd'** from *"funding_rounds.csv"* is the outcome variable and this numerical variable represents the total amount of money raised by a startup in a specific funding round, denominated in USD. It serves as the primary outcome of interest, quantifying the financial success of fundraising efforts. This variable is central to the research question as it directly quantifies the financial achievements of a startup's fundraising initiatives.
#
# **Independent Variables (X):**
# - **'pre_money_valuation'** from *"funding_rounds.csv"* is a numerical variable representing the valuation of a startup before receiving a new round of investment. It is a critical metric used to determine the equity stake that investors will receive in exchange for their capital. A higher pre-money valuation indicates a higher perceived value of the startup by investors. This variable is essential for understanding the dynamics of venture capital negotiations and the impact of valuation on fundraising success. It reflects investor confidence and the startup's growth prospects, serving as a benchmark for the financial health and potential of the startup company.
#
# - **'participants'** from *"funding_rounds.csv"* is a numerical variable indicates the number of investors participating in a given funding round. A higher number of participants can signal strong investor interest and competition, potentially increasing the total raised amount. It reflects the breadth of venture capital support and can be a representation for the size of VC networks and resources available to the startup.
#
# - **'fund_raised_amount'** from *"funds.csv"* is a numerical variable measures the amount of capital raised by venture capital funds themselves. Originally called **'raised_amount'**, the name of the varibale will be modified in the 'Data Cleaning' section due to the exsistence of the identical variable name in *"funding_rounds.csv"*. Although this variable focusing on the funds rather than the startups, it can indirectly reflect the investment capacity and aggressiveness of VC firms in the market. Larger fund sizes might indicate a greater willingness or ability to make substantial investments in startups, influencing the outcome of the total amount of money raised by a startup company in a specific funding round.
#
# - **'funding_round_code'** from *"funding_rounds.csv"* is a categorical variable categorizes the funding round such as Seed, Series A, Series B, etc. Different funding rounds attract different levels and types of VC interest, the stage of funding can influence both the likelihood and the amount of VC participation. Such that later rounds typically involving larger amounts and more established venture capital firms.

# %% [markdown]
# ## 1.2 Data Cleaning

# %% [markdown]
# In previous version of the project, the primary focus is on the table of *"funds.csv"* and *"funding_rounds.csv"* and the objective is to combine these two tables into a singular dataset tailored to our analytical needs.
#
# To prepare for this integration, first eliminate variables that do not contribute to our analysis, such as **'created_at'** and **'updated_at'**. These variables contributes solely to the dataset's management history, and have no relevance to the research objectives.

# %%
import pandas as pd

# Read the file of funds.csv
df = pd.read_csv('funds.csv')
# Drop the specified columns in funds.csv
df = df.drop(['id', 'created_at', 'updated_at'], axis=1)
# Write the modified DataFrame back to funds.csv
df.to_csv('funds.csv', index=False)

# Read the file of funding_rounds.csv
df = pd.read_csv('funding_rounds.csv')
# Drop the specified columns in funding_rounds.csv
df = df.drop(['id', 'created_by', 'created_at', 'updated_at'], axis=1)
# Write the modified DataFrame back to funding_rounds.csv
df.to_csv('funding_rounds.csv', index=False)

# %% [markdown]
# Additionally, to prevent ambiguity during the analysis, we will rename the variables in *"funds.csv"* which has identical variable names in *"funding_rounds"*. For example, the variable **'funded_at'** in *"funds.csv"* will be renamed to **'fund_funded'**. This is to distinguish different variables from the identical variable names in *"funds.csv"* and *"funding_rounds.csv"*.

# %%
# Read the funds.csv file
df = pd.read_csv('funds.csv')

# Rename the column
df = df.rename(columns={'funded_at': 'fund_funded'})
df = df.rename(columns={'object_id': 'fund_object_id'})
df = df.rename(columns={'raised_amount': 'fund_raised_amount'})
df = df.rename(columns={'raised_currency_code': 'fund_raised_currency_code'})
df = df.rename(columns={'source_url': 'fund_source_url'})
df = df.rename(columns={'source_description': 'fund_source_description'})
# Write the modified DataFrame back to the CSV
df.to_csv('funds.csv', index=False)

# %% [markdown]
# With the above adjustments, we will then merge the modified datasets to form a data foundation for the first phase of the research project.

# %%
# Load the datasets
df1 = pd.read_csv('funds.csv')
df2 = pd.read_csv('funding_rounds.csv')

# Combine the DataFrames horizontally
combined_df = pd.concat([df1, df2], axis=1)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('dataset_project_1.csv', index=False)

# Adjust data type for each column according to the  data
column_types = {
    'fund_object_id': object,
    'name': object,
    'fund_funded': object,
    'fund_raised_currency_code': object,
    'fund_source_url': object,
    'fund_source_description': object,
}
df = pd.read_csv('dataset_project_1.csv', dtype=column_types)

# Write the modified DataFrame back to the CSV
df.to_csv('dataset_project_1.csv', index=False)

# %% [markdown]
# Considering the potential impact of geographical factors on funding outcomes, we will enhance the current dataset by integrating the *"offices.csv"* table with the merged dataset *"dataset_project_1.csv"*. This integration will incorporate geographical variables such as cities and states in the United States from "offices.csv" into the dataset called *"dataset_project_2.csv"*.

# %%
# Read the file of offices.csv
df = pd.read_csv('offices.csv')
# Drop the specified columns in offices.csv
df = df.drop(['id', 'created_at', 'updated_at'], axis=1)
# Write the modified DataFrame back to offices.csv
df.to_csv('offices.csv', index=False)

# Load the datasets
df3 = pd.read_csv('dataset_project_1.csv')
df4 = pd.read_csv('offices.csv')
# Concatenate the DataFrames horizontally
combined_df = pd.concat([df3, df4], axis=1)
# Save the combined DataFrame to a new CSV file
combined_df.to_csv('dataset_project_2.csv', index=False)

# %% [markdown]
# ## 1.3 Summary Statistics Tables

# %% [markdown]
# **Summary Statistics for Outcome Variable (Y)**

# %%
from tabulate import tabulate

# Load the dataset
df = pd.read_csv('dataset_project_1.csv', low_memory=False)

# Convert 'raised_amount_usd' to numeric, handling any non-numeric values
df['raised_amount_usd'] = pd.to_numeric(df['raised_amount_usd'], errors='coerce')

# Convert 'raised_amount_usd' from USD to millions of USD
df['raised_amount_usd_millions'] = df['raised_amount_usd'] / 1e6

# Generate summary statistics for 'raised_amount_usd_millions'
summary_statistics_y = df['raised_amount_usd_millions'].describe()

# Convert the summary statistics to a DataFrame
summary_df = summary_statistics_y.reset_index()

# Drop the 'count' row from the summary statistics
summary_df = summary_df[summary_df['index'] != 'count']

# Format the numbers to two decimal places and add labels
summary_df['raised_amount_usd_millions'] = summary_df['raised_amount_usd_millions'].apply(lambda x: f"${x:.2f}M")

# Adding a title
print("Summary Statistics for Raised Amount (in Millions of USD):\n")

# Print the formatted table
summary_df.head(8)
# Out:
# Summary Statistics for Raised Amount (in Millions of USD):
#   index raised_amount_usd_millions
# 1  mean                     $7.95M
# 2   std                    $42.17M
# 3   min                     $0.00M
# 4   25%                     $0.25M
# 5   50%                     $1.60M
# 6   75%                     $6.70M
# 7   max                  $3835.05M

# %% [markdown]
# The table supports a comprehensive analysis of startup funding amounts. The average (mean) raised amount stands at approximately \\$7.95 million, suggesting that, startups in this dataset have secured substantial funding on average. However, the substantial standard deviation of approximately \\$42.17 million indicates a wide variance in the amounts raised by different startups, pointing to a highly diverse dataset where some startups raise significantly more capital than others.
#
# The smallest amount raised is \\$0, which could mean some startups haven't raised money through venture capital or there might be some missing information. A quarter of the startups raised \\$0.25 million or less, showing that not every startup gets a large amount of investment. The median is \\$1.6 million, meaning half the startups raised more than this and half raised less. This gives us a good sense of what a "typical" startup might raise, without the average being skewed by a few startups that raised huge amounts of money. The data also tells us that the top quarter of startups raised over \\$6.7 million. And at the very top, one startup raised an enormous $3.84 billion, highlighting that a few startups have been exceptionally successful in attracting VC funding.

# %% [markdown]
# **Summary Statistics for Independent Variables (X)**

# %%
# Load the dataset
df = pd.read_csv('dataset_project_1.csv', low_memory=False)

# Explicitly convert known numeric columns to numeric types, handling errors
numeric_columns = ['participants', 'fund_raised_amount', 'pre_money_valuation']
for column in numeric_columns:
    df[column] = pd.to_numeric(df[column], errors='coerce')

# Convert 'funding_round_code' to a categorical type as it's treated as categorical
df['funding_round_code'] = df['funding_round_code'].astype('category')

# Generate summary statistics for numerical variables
summary_numerical = df[numeric_columns].describe()

# Convert numerical values to millions of dollars for 'fund_raised_amount' and 'pre_money_valuation'
summary_numerical[['fund_raised_amount', 'pre_money_valuation']] /= 1e6

# Drop the 'count' row from the summary statistics
summary_numerical.drop('count', inplace=True)

# Format the numerical values to two decimal places
summary_numerical = summary_numerical.applymap(lambda x: f"{x:.2f}")

# Generate a frequency count for the categorical variable 'funding_round_code'
summary_categorical = df['funding_round_code'].value_counts()

# Display the results
print("Summary Statistics for Numerical Variables (Amounts in Millions of USD):")
summary_numerical.head(8)
# Out:
# Summary Statistics for Numerical Variables (Amounts in Millions of USD):
#      participants fund_raised_amount pre_money_valuation
# mean         1.53             399.48                0.33
# std          2.06            2468.49               65.32
# min          0.00               0.00                0.00
# 25%          0.00              16.30                0.00
# 50%          1.00             100.00                0.00
# 75%          2.00             275.00                0.00
# max         36.00           89000.00            15000.00

# %%
print("\nFrequency Counts for Different Funding Rounds (Summary Statistics for Categorical Variables):")
print(tabulate(summary_categorical.reset_index(), headers=['Funding Round Code', 'Counts'], tablefmt='github', showindex=False))
# Out:
# Frequency Counts for Different Funding Rounds (Summary Statistics for Categorical Variables):
# | Funding Round Code   |   Counts |
# |----------------------|----------|
# | unattributed         |    12227 |
# | seed                 |    11608 |
# | a                    |     7999 |
# | b                    |     4892 |
# | debt_round           |     3409 |
# | angel                |     3239 |
# | partial              |     3115 |
# | c                    |     2499 |
# | d                    |     1129 |
# | private_equity       |     1043 |
# | grant                |      776 |
# | e                    |      430 |
# | convertible          |      187 |
# | f                    |      145 |
# | crowd                |      111 |
# | post_ipo_equity      |       80 |
# | secondary_market     |       16 |
# | g                    |       13 |
# | post_ipo_debt        |        7 |
# | crowd_equity         |        3 |

# %% [markdown]
# On average, each funding round involves about 1.53 participants (VC firms or investors), indicating a collaborative or syndicated investment approach in many cases. The average (mean) fund raised amount is approximately \\$399.48 million, indicating that the venture capital funds involved have substantial financial resources at their disposal, on average. However, the vast standard deviation of about \\$2.47 billion points to significant disparities in the fund sizes, shifting from relatively modest funds to those with the capacity to invest billions of dollars. The minimum fund raised amount is $0, which may represent funds that are newly established or have not yet raised capital. The distribution of fund sizes shows that 25\% of the funds have raised \\$16.3 million or less, highlighting a segment of smaller or perhaps more specialized funds. The median fund size is \\$100 million, suggesting that half of the venture capital funds have raised this amount or less for investment. The upper quartile indicates that 75\% of funds have raised up to \\$275 million, while the maximum fund raised amount recorded is a staggering \\$89 billion, showcasing the potential for significant capital accumulation within the VC industry.
#
# The frequency counts for different funding rounds reveal a diverse array of investment stages. The most common category is 'unattributed', suggesting a significant number of funding activities where the specific round is not specified or does not fit traditional categorizations. This high count could indicate a wide variety of funding mechanisms that venture capital firms employ, some of which may not align neatly with standard round labels. The 'seed' round is the next most frequent, emphasizing the crucial role of early-stage financing. The prominence of seed funding reflects a strong VC focus on nurturing startups at their inception. The least common type is 'crowd equity', which involves raising small amounts of money from a large number of people, typically via online platforms. The rarity of crowd equity in this dataset might indicate while it's a growing area,  crowd equity still represents a minor part of overall VC activity compared to more traditional funding mechanisms. This diversity in funding rounds reflects the various phases of startup development that VCs invest in, from initial seed funding to significant late-stage investments.

# %% [markdown]
# ## 1.4 Data Visualization

# %% [markdown]
# **Histograms for Each Variable**

# %%
# !pip install seaborn > /dev/null 2>&1

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histogram for X variable 'participants'
plt.figure(figsize=(10, 6))
sns.histplot(df['participants'].dropna(), bins=30, color='green', edgecolor='black')
plt.title('Histogram of Participants (X)')
plt.xlabel('Participants')
plt.ylabel('Frequency')
plt.xlim([0, 10])
plt.grid(True)
plt.show()

# %% [markdown]
# From the Histogram of Participants, the majority of funding rounds have a low number of participants, with the frequency dramatically decreasing as the number of participants increases. This pattern could suggest that most startups attract a relatively small group of investors. The presence of funding rounds with more participants is less common, which might indicate that it is less typical for startups to have a large number of investors, or that only certain types of startups with certain growth potentials will attract wider interest. The skewness of the distribution towards to fewer participants, which could suggest that while venture capital participation is important, it is the quality fit of the investors, rather than the quantity, that might be more influential in determining the raised amounts. Additionally, the pattern observed may also reflect the market's structure where there are many small-scale investments and fewer large-scale investments.

# %%
# Load the dataset
df = pd.read_csv('dataset_project_1.csv', low_memory=False)

# Convert 'fund_raised_amount' to numeric, handling any non-numeric values
df['fund_raised_amount'] = pd.to_numeric(df['fund_raised_amount'], errors='coerce')

# Remove outliers using the IQR method
Q1 = df['fund_raised_amount'].quantile(0.25)
Q3 = df['fund_raised_amount'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
filtered_df = df[(df['fund_raised_amount'] >= lower_bound) & (df['fund_raised_amount'] <= upper_bound)]

# Plot histogram for 'fund_raised_amount' without outliers
plt.figure(figsize=(10, 6))
sns.histplot(filtered_df['fund_raised_amount'].dropna(), bins=30, color='green', edgecolor='black')
plt.title('Histogram of Fund Raised Amount (X)')
plt.xlabel('Raised Amount of Fund')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# The data is highly skewed to the right, meaning there are a lot of smaller funds and fewer very large funds. There is a significant concentration of funds in the lower end of the raised amount spectrum, which may indicate that while numerous VC funds are active, a majority manage to raise only modest amounts of capital. The tail extending to the right suggests that while most funds raise smaller amounts, there are outliers that have raised vast sums, possibly into the billions. The concentration of smaller funds could imply a competitive market where only a few funds manage to secure large investments, potentially impacting their ability to participate in larger or more numerous funding rounds for startups. Conversely, the presence of funds with very large raised amounts highlights the existence of highly influential players in the VC market, and they are capable of making significant investments that could drive the growth of multiple startups or fund larger, more established companies.

# %%
# Count plot for X variable 'funding_round_code' 
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='funding_round_code', stat='count', discrete=True, shrink=1, color='green', edgecolor='black')
plt.xticks(rotation=55)
plt.title('Histogram of Funding Round Codes (X)')
plt.xlabel('Funding Round Code')
plt.ylabel('Count')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# The observed pattern in the histogram shows a high frequency of 'seed' and 'unattributed' funding rounds, we are unable to tell the exact reason of the exsistence of 'unattributed'. However, the second largest frequency of companies receiving 'seed' capital which suggests a strong VC focus on early-stage investments. This could mean that venture capital's participation has a significant impact on startups in their formative stages, where the amounts raised are essential for survival and initial growth. The 'Series A' and 'Series B' rounds also have a notable presence, indicating continued VC support as startups progress. However, the drastic drop-off in frequency for later stages like 'Series D' and beyond suggests that fewer startups reach these advanced funding stages or they do not require as many rounds of funding due to larger amounts being raised in earlier rounds. The relative scarcity of specialized funding types such as 'debt_round', 'post_ipo_equity', and 'secondary_market' indicates that traditional equity-based financing rounds are the primary mechanism through which startups raise funds from venture capital.

# %%
# Load the dataset
df = pd.read_csv('dataset_project_1.csv', low_memory=False)

# Convert 'raised_amount_usd' to numeric, handling any non-numeric values
df['raised_amount_usd'] = pd.to_numeric(df['raised_amount_usd'], errors='coerce')

# Remove outliers using the IQR method
Q1 = df['raised_amount_usd'].quantile(0.25)
Q3 = df['raised_amount_usd'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
filtered_df = df[(df['raised_amount_usd'] >= lower_bound) & (df['raised_amount_usd'] <= upper_bound)]

# Plot histogram for 'raised_amount_usd' without outliers
plt.figure(figsize=(10, 6))
sns.histplot(filtered_df['raised_amount_usd'].dropna(), bins=30, color='blue', edgecolor='black')
plt.title('Histogram of Raised Amount USD (Y)')
plt.xlabel('Raised Amount USD')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# Based on the historgram, the majority of startups have raised amounts on the lower end of the spectrum. This sign suggesting that while many startups do receive funding, large-scale investments are less frequent. The concentration of data at the lower end of the raised amount axis indicates that smaller funding rounds are very common. This could mean that most venture capital investments are cautious or that startups typically seek smaller amounts in the early stages of their growth. The long tail extending towards the higher values, which with a significantly lower frequency, suggests that a small number of startups have raised very large sums of money. This could reflect those startups with particularly promising prospects or those in later stages of growth attract significant amount of investment.

# %% [markdown]
# **Relationship between the Outcome (Y) and Different Individual Variables (X)**

# %%
# Load the dataset
df = pd.read_csv('dataset_project_1.csv', low_memory=False)

# Convert relevant columns to numeric
df['raised_amount_usd'] = pd.to_numeric(df['raised_amount_usd'], errors='coerce')
df['participants'] = pd.to_numeric(df['participants'], errors='coerce')

# Plotting a bar plot for the relationship between 'participants' and 'raised_amount_usd'
plt.figure(figsize=(10, 6))
sns.barplot(x='participants', y='raised_amount_usd', data=df, color="grey")
plt.title("Raised Amount USD vs. Participants")
plt.xlabel("Participants")
plt.ylabel("Raised Amount USD")
plt.show()

# %% [markdown]
# This bar plot of 'Raised Amount USD vs. Participants' demonstrates whether there is an apparent trend or pattern indicating that more VC participation correlates with an increase in the amount of money raised. There is a high concentration of data points with a lower number of participants. Most startups have fewer than five venture capital participants in their funding rounds. There are some outliers with very high raised amounts, indicating a few startups have raised significant amount of money. These could represent particularly successful funding rounds or later-stage investments. At first glance, there isn't a clear upward trend that would suggest more participants correlate with higher raised amounts. While there are some instances of startups with more participants raising large amounts of money, the overall pattern does not strongly indicate that more VC participants consistently lead to higher fundraising outcomes. Thus the scatter plot suggests that while having more venture capital participants in a funding round may contribute to some high-raise success stories, it is not a uniform rule, and many startups with fewer participants also manage to secure significant funding. This could imply that other factors play a crucial role in determining the amount raised, such as the quality of the participants, the startup's growth potential, market conditions, or the stage of the funding round etc.

# %%
# Load the dataset
df = pd.read_csv('dataset_project_1.csv', low_memory=False)

# Convert relevant columns to numeric
df['raised_amount_usd'] = pd.to_numeric(df['raised_amount_usd'], errors='coerce')
df['fund_raised_amount'] = pd.to_numeric(df['fund_raised_amount'], errors='coerce')

# Remove outliers using the IQR method
Q1 = df['fund_raised_amount'].quantile(0.25)
Q3 = df['fund_raised_amount'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
filtered_df = df[(df['fund_raised_amount'] >= lower_bound) & (df['fund_raised_amount'] <= upper_bound)]

# Plotting Y ('raised_amount_usd') vs. X ('fund_raised_amount') without outliers
plt.figure(figsize=(10, 6))
sns.scatterplot(x='fund_raised_amount', y='raised_amount_usd', data=filtered_df, color="black", alpha=0.2)
plt.title("Raised Amount USD vs. Raised Amount of Fund")
plt.xlabel("Fund Raised Amount")
plt.ylabel("Raised Amount USD")
plt.show()

# %% [markdown]
# By analyzing the relationship of 'Raised Amount USD vs. Raised Amount of Fund', we are likely to find out whether there is a tendency for startups to raise more money when associated with VC funds that have larger amounts of capital. There is a dense concentration of points where both the VC's fund raised amount and the startups' raised amounts are lower, suggesting that a majority of startups and VC funds operate with relatively modest amounts of capital. There are fewer instances where both the VC funds and startups have high raised amounts, which may indicate that only a select few VC funds have large capital reserves, and only a few startups manage to secure large funding. The scatter plot does not immediately suggest a strong linear relationship where higher fund raised amounts directly correspond to higher startup raised amounts. While there are data points spread across the plot, indicating some level of correlation, the relationship is not evidently linear and suggests that other factors may also significantly influence the raised amounts for startups. The lack of a clear linear trend implies that while the resources of VC funds are important, they may not be the main determining factor of the amounts that startups raise. This could mean that other elements, such as the market potential, the expertise of the founders, and the strategic fit between the startup and the VC fund play significant roles. This aligns with the complex nature of venture capital investment, where strategic considerations often outweigh sheer financial capacity.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('dataset_project_1.csv', low_memory=False)

# Convert 'raised_amount_usd' to numeric
df['raised_amount_usd'] = pd.to_numeric(df['raised_amount_usd'], errors='coerce')

# Remove outliers using the IQR method for 'raised_amount_usd'
Q1 = df['raised_amount_usd'].quantile(0.25)
Q3 = df['raised_amount_usd'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
filtered_df = df[(df['raised_amount_usd'] >= lower_bound) & (df['raised_amount_usd'] <= upper_bound)]

# Sorting the categories based on their median raised amounts in descending order
order = filtered_df.groupby('funding_round_code')['raised_amount_usd'].median().sort_values(ascending=False).index

# Plotting Y ('raised_amount_usd') vs. X ('funding_round_code') with outliers removed
plt.figure(figsize=(12, 6))
sns.stripplot(data=filtered_df, x='funding_round_code', y='raised_amount_usd', jitter=True, color="black", alpha=0.2, order=order)
plt.xticks(rotation=50)
plt.title('Strip Plot of Raised Amount USD Presented by the Frequency of Funding Round Code')
plt.xlabel('Funding Round Code')
plt.ylabel('Raised Amount USD')
plt.show()

# %% [markdown]
# There is considerable variation in the amounts raised within each funding round category. This indicates that while there might be typical amounts associated with each stage, individual startups' experiences can vary widely. At the same time, this plot shows many outliers, particularly in later funding rounds such as 'Series D' and 'Series E', where individual startups have raised significant amounts of money. This might be reflective of startups that have shown notable growth or promise will more likely to attract larger investments. Some funding round categories, like 'seed' and 'Series A', have a higher density of data points, suggesting these are common stages for startups to raise funds. The density diminishes in later stages, like 'Series D' and 'Series E', which may imply that fewer startups reach these later funding rounds or that they do not require publicized funding rounds due to other sources of capital. The 'unattributed' category has the most significant number of points, indicating many funding events where the round is not specified. This could suggest informal rounds, internal rounds, or a classification issue within the dataset. The variability within each funding round category and the presence of outliers suggest that the amount raised is influenced by more than just the stage of the funding round. This implies that other factors, such as the startup's industry, the business model, the track record, and the economic context, are also matters.

# %% [markdown]
# **Covariates and Their Correlation with the Outcome (Y)**

# %%
# Load the dataset
df = pd.read_csv('dataset_project_1.csv', low_memory=False)

# Convert relevant columns to numeric, handling errors
columns_to_convert = ['raised_amount_usd', 'pre_money_valuation_usd', 'post_money_valuation_usd']
for column in columns_to_convert:
    df[column] = pd.to_numeric(df[column], errors='coerce')

# Define bins for valuation ranges and categorize valuations, removing the '>1B' category
valuation_bins = [0, 1e6, 1e7, 1e8, 1e9]
bin_labels = ['<1M', '1M-10M', '10M-100M', '100M-1B']
df['Pre-Money Valuation Category'] = pd.cut(df['pre_money_valuation_usd'], bins=valuation_bins, labels=bin_labels, right=False)

# Remove outliers for 'raised_amount_usd' using the IQR method
Q1 = df['raised_amount_usd'].quantile(0.25)
Q3 = df['raised_amount_usd'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
filtered_df = df[(df['raised_amount_usd'] >= lower_bound) & (df['raised_amount_usd'] <= upper_bound)]

# Plotting boxplot for pre-money valuation category without outliers
plt.figure(figsize=(12, 6))
sns.boxplot(data=filtered_df, x='Pre-Money Valuation Category', y='raised_amount_usd', color='salmon')  
plt.title('Raised Amount USD by Pre-Money Valuation Category')
plt.xlabel('Pre-Money Valuation Category')
plt.ylabel('Raised Amount USD')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Pre-money valuation is a key covariate because it gives venture capitalists an idea of what the company is worth before they put their money into it. This valuation is often used to determine how much equity a VC will receive for their investment, making it relevant to the research topic. This plot of 'Raised Amount USD by Pre-Money Valuation Category' provides a visual representation of how startups at different valuation levels are able to raise funds. From the boxplot above, we can tell the range of raised amounts tends to increase with higher pre-money valuation categories. This suggests that startups with higher valuations are able to raise larger amounts of money. The median raised amounts also seem to increase with valuation categories, indicating that as the perceived value of a company increases, so does the typical (median) amount of funding it receives. There are outliers across all categories but particularly in the higher valuation section, and these are startups that have raised amounts significantly higher than their peers in the same valuation category. The boxplot above suggests that there's a positive correlation between pre-money valuation and the amount of money raised. Startups with higher valuations before fundraising seem to have better outcomes in raising capital. This could be because higher valuations reflect a startup's potential for growth and profitability, which in turn attracts more investment.

# %% [markdown]
# ## 2.1 The Message

# %% [markdown]
# From the previous analysis, we observed a potential positive correlation between pre-money valuation and the startup's raised amount，which implies that startups with higher pre-money valuations are likely to receive larger fundraising amounts.

# %%
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('dataset_project_1.csv', low_memory=False)

# Convert relevant columns to numeric
df['raised_amount_usd'] = pd.to_numeric(df['raised_amount_usd'], errors='coerce')
df['pre_money_valuation_usd'] = pd.to_numeric(df['pre_money_valuation_usd'], errors='coerce')

# Remove rows where pre_money_valuation_usd is zero
df = df[df['pre_money_valuation_usd'] != 0]

# Convert the 'fund_funded' column to datetime format
df['fund_funded'] = pd.to_datetime(df['fund_funded'])

# Group by year and calculate the average for each variable
df_yearly = df.groupby(df['fund_funded'].dt.year)[['raised_amount_usd', 'pre_money_valuation_usd']].mean()

# Normalize the variables to start from the same point
df_yearly['raised_amount_usd_indexed'] = df_yearly['raised_amount_usd'] / df_yearly['raised_amount_usd'].iloc[0] * 100
df_yearly['pre_money_valuation_usd_indexed'] = df_yearly['pre_money_valuation_usd'] / df_yearly['pre_money_valuation_usd'].iloc[0] * 100

# Plotting separate graphs side by side
fig, axes = plt.subplots(1, 2, figsize=(20, 6))

# Plot Raised Amount USD
axes[0].plot(df_yearly.index, df_yearly['raised_amount_usd_indexed'], color='red', label='Raised Amount USD', marker='o')
axes[0].set_title('Trend of Raised Amount USD')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Indexed Value')
axes[0].grid(True)
axes[0].legend()

# Plot Pre-Money Valuation USD
axes[1].plot(df_yearly.index, df_yearly['pre_money_valuation_usd_indexed'], color='blue', label='Pre-Money Valuation USD', marker='o')
axes[1].set_title('Trend of Pre-Money Valuation USD')
axes[1].set_xlabel('Year')
axes[1].set_ylabel('Indexed Value')
axes[1].grid(True)
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# The line plots above illustrate a similar trend in both variables, suggesting a positive relationship between pre-money valuation and the amount raised by startups.
#
# For "Trend of Raised Amount USD," there is a pronounced peak around 2012, indicating a year of particularly high investment activity. This spike could be the result of a variety of factors, such as market growth, increased investor confidence, or a cluster of successful funding rounds for startups in that period.
#
# On the other hand, "Trend of Pre-Money Valuation USD" shows a gradual increase over the years with a substantial spike also occurring around 2012. This peak in pre-money valuation suggests that during the same period when fundraising was at its height, startups were also being valued more highly before they received investments.
#
# The parallel in timing between these spikes in both raised funds and pre-money valuation suggests that there is likely a positive correlation between the two variables, which supports the main message. As when startups have higher pre-money valuations, they may be able to attract more significant investment amounts, possibly due to investor perception of their potential for growth or return on investment.

# %% [markdown]
# ## 2.2 Maps and Interpretations

# %% [markdown]
# This research includes a total of five maps, each depicting the mainland United States with all financial data uniformly expressed in millions of U.S. dollars. The first three maps directly relate to the main message of the study, illustrating the key findings and patterns across states. The last two maps are interactive maps that extends our exploration, allowing for a potentially related dimensions of the research.

# %%
#!pip install qeds fiona geopandas xgboost gensim folium pyLDAvis descartes

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from shapely.geometry import Point
# %matplotlib inline

# %% [markdown]
# ### Map 1: Total Pre-Money Valuation by State

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('dataset_project_2.csv', low_memory=False)

# Calculate the total pre-money valuation for each state code
total_valuation = df.groupby('state_code')['pre_money_valuation'].sum().reset_index()

# Rename the column for clarity
total_valuation.rename(columns={'pre_money_valuation': 'total_pre_money_valuation'}, inplace=True)

# Convert the total pre-money valuation to millions
total_valuation['total_pre_money_valuation'] = total_valuation['total_pre_money_valuation'] / 1e6

# Setting the path to the shapefile
SHAPEFILE = '/Users/project-one-code-yianxiong/ECO225Project/Data/cb_2018_us_state_20m.shp'

# Read the shapefile into a GeoDataFrame
gdf = gpd.read_file(SHAPEFILE)

# Filter out Alaska and minor islands
gdf = gdf[(gdf['STUSPS'] != 'AK') & (gdf['STUSPS'] != 'HI') & (gdf['STUSPS'] != 'PR') & (gdf['STUSPS'] != 'VI') & (gdf['STUSPS'] != 'MP') & (gdf['STUSPS'] != 'GU') & (gdf['STUSPS'] != 'AS') & (gdf['STUSPS'] != 'AK')]

# Merge the total valuation data with the GeoDataFrame
merged_gdf = gdf.merge(total_valuation, left_on='STUSPS', right_on='state_code', how='left')

# Plotting the heatmap
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
merged_gdf.plot(column='total_pre_money_valuation', ax=ax, legend=True, cmap='coolwarm', edgecolor='black')

# Add state initials at the centroid of each state
for idx, row in merged_gdf.iterrows():
    ax.annotate(text=row['STUSPS'], xy=(row['geometry'].centroid.x, row['geometry'].centroid.y), ha='center', fontsize=8)

plt.title('Total Pre-Money Valuation by State (Mainland US, in Millions)')
plt.show()

# %% [markdown]
# The first map visualizes the total pre-money valuation by state across the mainland United States, expressed in millions of U.S. dollars. California (CA) is immediately noticeable with its strikingly high valuation, dwarfing other states' figures significantly. This indicates that California's startup ecosystem is likely the most robust in terms of the valuation of companies prior to fundraising, which could be attributed to the presence of Silicon Valley and a high concentration of tech startups that traditionally command higher valuations (Elvira, 2023).
#
# In contrast, while New York (NY) presents a faint difference in pre-money valuation from other states, it does not approach California's level, yet it still reflects a significant and competitive entrepreneurial presence.

# %% [markdown]
# ### Map 2: Average Pre-Money Valuation by State

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('dataset_project_2.csv', low_memory=False)

# Calculate the average pre-money valuation for each state code
average_valuation = df.groupby('state_code')['pre_money_valuation'].mean().reset_index()

# Rename the column for clarity
average_valuation.rename(columns={'pre_money_valuation': 'average_pre_money_valuation'}, inplace=True)

# Convert the average pre-money valuation to millions
average_valuation['average_pre_money_valuation'] = average_valuation['average_pre_money_valuation'] / 1e6

# Setting the path to the shapefile
SHAPEFILE = '/Users/project-one-code-yianxiong/ECO225Project/Data/cb_2018_us_state_20m.shp'

# Read the shapefile into a GeoDataFrame
gdf = gpd.read_file(SHAPEFILE)

# Filter out Alaska and minor islands
gdf = gdf[(gdf['STUSPS'] != 'AK') & (gdf['STUSPS'] != 'HI') & (gdf['STUSPS'] != 'PR') & (gdf['STUSPS'] != 'VI') & (gdf['STUSPS'] != 'MP') & (gdf['STUSPS'] != 'GU') & (gdf['STUSPS'] != 'AS') & (gdf['STUSPS'] != 'AK')]

# Merge the average valuation data with the GeoDataFrame
merged_gdf = gdf.merge(average_valuation, left_on='STUSPS', right_on='state_code', how='left')

# Plotting the heatmap
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
merged_gdf.plot(column='average_pre_money_valuation', ax=ax, legend=True, cmap='coolwarm', edgecolor='black')

# Add state initials at the centroid of each state
for idx, row in merged_gdf.iterrows():
    ax.annotate(text=row['STUSPS'], xy=(row['geometry'].centroid.x, row['geometry'].centroid.y), ha='center', fontsize=8)

plt.title('Average Pre-Money Valuation by State (Mainland US, in Millions)')
plt.show()

# %% [markdown]
# Again, California shows a very high pre-money valuation relative to other states. This suggests that startups in California are valued more highly on average before they receive investment. High average pre-money valuations can indicate a robust startup ecosystem with a competitive market for venture capital, where investors are willing to pay more for equity stakes, potentially due to the expectation of higher growth and returns.
#
# Alongside California, New York also distinguishes itself similar to the first map, signaling its own strong startup environment. The notable valuations here hint at New York's significant role in the nation's startup economy, likely driven by its own set of flourishing industries and investor activities.

# %% [markdown]
# ### Map 3: Total Amount of Funding Raised by State

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('dataset_project_2.csv', low_memory=False)

# Calculate the average pre-money valuation for each state code
total_raised_amount = df.groupby('state_code')['raised_amount_usd'].sum().reset_index()

# Rename the column for clarity
total_raised_amount.rename(columns={'raised_amount_usd': 'total_raised_amount_usd'}, inplace=True)

# Convert the average pre-money valuation to millions
total_raised_amount['total_raised_amount_usd'] = total_raised_amount['total_raised_amount_usd'] / 1e6

# Setting the path to the shapefile
SHAPEFILE = '/Users/project-one-code-yianxiong/ECO225Project/Data/cb_2018_us_state_20m.shp'

# Read the shapefile into a GeoDataFrame
gdf = gpd.read_file(SHAPEFILE)

# Filter out Alaska and minor islands
gdf = gdf[(gdf['STUSPS'] != 'AK') & (gdf['STUSPS'] != 'HI') & (gdf['STUSPS'] != 'PR') & (gdf['STUSPS'] != 'VI') & (gdf['STUSPS'] != 'MP') & (gdf['STUSPS'] != 'GU') & (gdf['STUSPS'] != 'AS')]

# Merge the average valuation data with the GeoDataFrame
merged_gdf = gdf.merge(total_raised_amount, left_on='STUSPS', right_on='state_code', how='left')

# Plotting the heatmap
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
merged_gdf.plot(column='total_raised_amount_usd', ax=ax, legend=True, cmap='coolwarm', edgecolor='black')

# Add state initials at the centroid of each state
for idx, row in merged_gdf.iterrows():
    ax.annotate(text=row['STUSPS'], xy=(row['geometry'].centroid.x, row['geometry'].centroid.y), ha='center', fontsize=8)

plt.title('Total Amount of Funding Raised by State (Mainland US, in Millions)')
plt.show()

# %% [markdown]
# When comparing the map displaying the dependent variable of funding amount raised with the prior maps detailing the independent variable of pre-money valuation, California's dominance is once again evident through its unmatched total funding amount. Concurrently, New York's presence becomes more pronounced, maintaining its status as the second most noticeable state, in alignment with its standing in the previous maps. Furthermore, the resemblance between the map illustrating total funding raised and the maps representing both average and total pre-money valuation underpins the hypothesized positive correlation between these two variables.

# %% [markdown]
# ### Map 4: Average Amount of Funding Raised by State

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('dataset_project_2.csv', low_memory=False)

# Calculate the mean raised amount for each state code
mean_raised_amount = df.groupby('state_code')['raised_amount_usd'].mean().reset_index()

# Rename the column for clarity
mean_raised_amount.rename(columns={'raised_amount_usd': 'mean_raised_amount_usd'}, inplace=True)

# Convert the mean raised amount to millions
mean_raised_amount['mean_raised_amount_usd'] = mean_raised_amount['mean_raised_amount_usd'] / 1e6

# Setting the path to the shapefile
SHAPEFILE = '/Users/project-one-code-yianxiong/ECO225Project/Data/cb_2018_us_state_20m.shp'

# Read the shapefile into a GeoDataFrame
gdf = gpd.read_file(SHAPEFILE)

# Filter out Alaska and minor islands
gdf = gdf[(gdf['STUSPS'] != 'AK') & (gdf['STUSPS'] != 'HI') & (gdf['STUSPS'] != 'PR') & (gdf['STUSPS'] != 'VI') & (gdf['STUSPS'] != 'MP') & (gdf['STUSPS'] != 'GU') & (gdf['STUSPS'] != 'AS')]

# Merge the mean raised amount data with the GeoDataFrame
merged_gdf = gdf.merge(mean_raised_amount, left_on='STUSPS', right_on='state_code', how='left')

# Plotting the heatmap
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
merged_gdf.plot(column='mean_raised_amount_usd', ax=ax, legend=True, cmap='coolwarm', edgecolor='black')

# Add state initials at the centroid of each state
for idx, row in merged_gdf.iterrows():
    ax.annotate(text=row['STUSPS'], xy=(row['geometry'].centroid.x, row['geometry'].centroid.y), ha='center', fontsize=8)

plt.title('Average Amount of Funding Raised by State (Mainland US, in Millions)')
plt.show()

# %% [markdown]
# The average funding amount map tells a different story. In this map, California doesn't show as significant an outlier status as in the previous maps. This could indicate that while the total funding amount is high, the individual rounds are not significantly larger than those in other states when averaged out. It suggests a large number of funding rounds occurring, which, when averaged, results in a more modest figure relative to states that may have fewer but larger individual rounds. The contrast between this map and the one depicting total funding may illuminate the investment strategies across states: some that are characterized by several large-scale deals and others marked by a higher volume of smaller transactions.

# %% [markdown]
# ### Map 5: Median Amount of Funding Raised by State

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('dataset_project_2.csv', low_memory=False)

# Calculate the median raised amount for each state code
median_raised_amount = df.groupby('state_code')['raised_amount_usd'].median().reset_index()

# Rename the column for clarity
median_raised_amount.rename(columns={'raised_amount_usd': 'median_raised_amount_usd'}, inplace=True)

# Convert the median raised amount to millions
median_raised_amount['median_raised_amount_usd'] = median_raised_amount['median_raised_amount_usd'] / 1e6

# Setting the path to the shapefile
SHAPEFILE = '/Users/project-one-code-yianxiong/ECO225Project/Data/cb_2018_us_state_20m.shp'

# Read the shapefile into a GeoDataFrame
gdf = gpd.read_file(SHAPEFILE)

# Filter out Alaska and minor islands
gdf = gdf[(gdf['STUSPS'] != 'AK') & (gdf['STUSPS'] != 'HI') & (gdf['STUSPS'] != 'PR') & (gdf['STUSPS'] != 'VI') & (gdf['STUSPS'] != 'MP') & (gdf['STUSPS'] != 'GU') & (gdf['STUSPS'] != 'AS')]

# Merge the median raised amount data with the GeoDataFrame
merged_gdf = gdf.merge(median_raised_amount, left_on='STUSPS', right_on='state_code', how='left')

# Plotting the heatmap
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
merged_gdf.plot(column='median_raised_amount_usd', ax=ax, legend=True, cmap='coolwarm', edgecolor='black')

# Add state initials at the centroid of each state
for idx, row in merged_gdf.iterrows():
    ax.annotate(text=row['STUSPS'], xy=(row['geometry'].centroid.x, row['geometry'].centroid.y), ha='center', fontsize=8)

plt.title('Median Amount of Funding Raised by State (Mainland US, in Millions)')
plt.show()

# %% [markdown]
# In the map showcasing the median amount of funding raised by state, it's noticeable that certain states, like Wyoming (WY) and Alabama (AL), stand out with a higher median funding amount compared to surrounding states. This could suggest that while the total amount of funding and the average pre-money valuation in places like California may be higher due to a larger number of deals, the median funding amount in states like Wyoming and Alabama is significant in its own right. The high median values in these two states could be due to a smaller number of funding rounds that are relatively large. This might indicate a few companies securing substantial investments, which elevates the median despite a lower total funding amount compared to a state like California.
#
# The difference between median and average amounts can be influenced by outliers. States like California may have many funding rounds, including several exceptionally large ones that raise the average, but the median would be less influenced by those outliers and could represent the 'typical' funding round size more accurately.
#
# The observation that some states with a high median funding amount don't necessarily show high averages could point to different investment dynamics. For instance, states with high averages may have highly successful startups that can attract large sums and skewing the average upwards, while states with high medians might have more consistently sized rounds that reflect a more stable investment climate.
#
# Connecting this to the main research message, it's important to note that averages can be skewed by large outliers, and medians can provide a different perspective that might be more representative of the typical funding round. When looking at pre-money valuations and their relationship to the raised amount, it would be beneficial to consider both the mean and median to get a full picture of the investment landscape. The presence of states like Wyoming and Alabama with high median values despite not being known for massive total funding indicates a more complex relationship that could be explored further.

# %% [markdown]
# ## 3.1 Potential Data to Scrape

# %% [markdown]
# **Why This Data Enhances the Paper:** The inclusion of household income data can help estimate the bootstrapping potential of startup founders. In the early stages of a startup, particularly pre-seed, founders often rely on personal funds or bootstrapping to finance their ventures (Kenton, 2024). Higher household incomes in certain regions may indicate a greater capacity for founders to invest in their own startups, which could influence the pre-money valuation, initial fundraising success and the trajectory of venture capital dynamics.
#
# The inclusion of income data can also reflect on the economic environment of different regions and its influence on startup fundraising. Higher income levels might indicate a more affluent population and potentially more investment opportunities, which could impact the amount of venture capital raised. By analyzing this aspect, our research can offer a more comprehensive understanding of the factors affecting fundraising success.
#
# **Data Source:** The household income data can be scraped from the Wikipedia page "List of U.S. states and territories by income" available at [this link](https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_income).
#
# **Merging the Data and Utilizing the New Information:**
# To merge the scraped income data with the existing dataset, a common variable such as 'state' or 'year' can be used to match the geographical and temporal dimensions. Once merged, the extended dataset can be analyzed to explore how regional household income levels (indicating bootstrapping potential) correlate with the amounts raised in funding rounds, especially in the pre-seed stage.
#
# By integrating this additional dimension of household income into the analysis, the research can offer a more comprehensive perspective on the initial funding dynamics of startups and the role of personal financial resources in the venture capital ecosystem. This approach can provide valuable insights into the economic factors influencing startup development and fundraising success.

# %% [markdown]
# ## 3.2 Potential Challenges

# %% [markdown]
# In evaluating the relationship between regional household incomes and startup funding, it's important to recognize that higher income levels don't necessarily equate to greater funding opportunities for startups. The presence of a higher cost of living in affluent areas may offset the advantages of wealth, and income reports alone don't capture the full financial picture. Individuals in lower-income brackets may have access to capital through assets or networks that aren't reflected in their income, adding layers of nuance to any correlation between income and startup success.
#
# As for the technical aspects of integrating web-scraped data, challenges such as formatting inconsistencies are indeed common in data scraping. These include the need to strip currency symbols for numerical analysis and to standardize column names for seamless integration into existing datasets. While these tasks are routine in the context of data scraping, they are critical to ensuring the scraped data is analyzable and comparable within the framework of our research.

# %% [markdown]
# ## 3.3 Scraping the Data

# %% [markdown]
# **Step 1. Request the URL:**

# %%
import requests

web_url = 'https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_income'
response = requests.get(web_url)

# %% [markdown]
# The first step uses the "requests" library to send an HTTP GET request to the URL of the webpage that we want to scrape. This request retrieves the content of the webpage, which is typically in HTML format.

# %% [markdown]
# **Step 2. Get the Soup object:**

# %%
from bs4 import BeautifulSoup

soup_object = BeautifulSoup(response.content)

# %% [markdown]
# Once we have the webpage content, use the BeautifulSoup library to parse the HTML. This creates a BeautifulSoup object, which provides methods and properties to navigate and search the HTML tree. This object is often referred to as the "soup."

# %% [markdown]
# **Step 3. Find the relevant tags:**

# %%
# Find the first 'table' in the soup object
data_table = soup.find('table', class_='wikitable')

# %% [markdown]
# In this step, we use the 'find' method of the BeautifulSoup object to locate the HTML elements that contain the data we want to extract. In this case, we are interested in scraping a table, then we look for \<table> tags. We also need to specify additional attributes to narrow down the search, such as the class table, 'wikitable'.

# %% [markdown]
# **Step 4. Find the values:**

# %%
all_rows = data_table.find_all('tr')
for row in all_rows[1:]:  # Skip the header row
    cols = row.find_all('td')
    if len(cols) >= 14:  # Ensure there are enough columns
        col_data = [ele.text.strip() for ele in cols[:14]]

# %% [markdown]
# Once we have the table element, we can iterate through its rows (\<tr> tags) and cells (\<td> tags) to extract the text content of each cell. This is where to retrieve the actual data from the HTML structure.

# %% [markdown]
# **Step 5. Write a for-loop and put the data into a dataframe structure:**

# %%
import pandas as pd

columns = [th.text.strip() for th in all_rows[0].find_all('th')][:14]
web_scraped_data = pd.DataFrame(columns=columns)

for col_data in data:
    web_scraped_data = web_scraped_data.append(pd.Series(col_data, index=columns), ignore_index=True)

# %% [markdown]
# After extracting the data from the HTML elements, we can organize it into a structured format. A common approach is to store the data in a pandas DataFrame, which provides a structure similar to a spreadsheet. This involves creating a DataFrame and appending rows of data to it in a loop.

# %% [markdown]
# **Step 6. Save the Scraped Data into a .csv File**

# %%
web_scraped_data.to_csv('web_scraped_data.csv', index=False)

# %% [markdown]
# Finally, we can save the DataFrame containing the scraped data to a CSV file using the to_csv method.

# %% [markdown]
# ## 3.4 Merging the Scraped Dataset

# %% [markdown]
# Before proceeding with the merging process, it is essential to clean the scraped data as outlined in section 3.2. Once cleaned, the dataset should be saved in its modified form, setting the stage for the merging process that follows.

# %%
import pandas as pd

# Load the scraped data from the CSV file
scraped_data = pd.read_csv('/Users/project-one-code-yianxiong/ECO225Project/Data/web_scraped_data.csv')

# Clean the column names
new_column_names = []
for col in scraped_data.columns:
    if col == scraped_data.columns[-1]:
        new_column_names.append('web_avg_gr_2010_income_to_2021_percentage')
    elif col == scraped_data.columns[0]:
        new_column_names.append('web_state_rank_income')
    elif col == scraped_data.columns[1]:
        new_column_names.append('web_state_name_income')
    else:
        new_column_names.append('web_income_' + col.lower())

scraped_data.columns = new_column_names

# Remove dollar signs and convert income data to numerical
for col in scraped_data.columns[2:-1]:  # Skip the first two columns and the last one
    scraped_data[col] = scraped_data[col].replace({'\$': '', ',': ''}, regex=True).astype(float)

# Remove the percentage sign from the last column and convert it to a numerical variable
scraped_data['web_avg_gr_2010_income_to_2021_percentage'] = scraped_data['web_avg_gr_2010_income_to_2021_percentage'].replace({'%': ''}, regex=True).astype(float)

# Save the modified data to a new CSV file
scraped_data.to_csv('/Users/project-one-code-yianxiong/ECO225Project/Data/web_scraped_modified.csv', index=False)

# Display the first few rows of the modified data
scraped_data.head()
# Out:
#   web_state_rank_income web_state_name_income  web_income_2021  \
# 0                   NaN         United States          69717.0
# 1                     –      Washington, D.C.          90088.0
# 2                     1              Maryland          90203.0
# 3                     2         Massachusetts          89645.0
# 4                     3            New Jersey          89296.0
#
#    web_income_2019  web_income_2018  web_income_2017  web_income_2016  \
# 0          65712.0          63179.0          60336.0          57617.0
# 1          92266.0          85203.0          82372.0          75506.0
# 2          86738.0          83242.0          80776.0          78945.0
# 3          85843.0          79835.0          77385.0          75297.0
# 4          85751.0          81740.0          80088.0          76126.0
#
#    web_income_2015  web_income_2014  web_income_2013  web_income_2012  \
# 0          55775.0          53657.0          52250.0          51371.0
# ...

# %% [markdown]
# After completing the data cleaning process, we are ready to merge our modified version of the scraped data with our existing dataset, *"dataset_project_2.csv"*. The merged dataset will be saved as *"dataset_project_3.csv"*, which we can use for future analysis.

# %%
import pandas as pd

# Load the datasets
dataset_project_2 = pd.read_csv('/Users/project-one-code-yianxiong/ECO225Project/Data/dataset_project_2.csv', low_memory=False)
web_scraped_modified = pd.read_csv('/Users/project-one-code-yianxiong/ECO225Project/Data/web_scraped_modified.csv', low_memory=False)

# Concatenate the datasets horizontally
dataset_project_3 = pd.concat([dataset_project_2, web_scraped_modified], axis=1)

# Save the merged dataset to a new CSV file
dataset_project_3.to_csv('dataset_project_3.csv', index=False)

# %% [markdown]
# ## 3.5 Visualizing the Scraped Dataset

# %% [markdown]
# According to section 2.1, the main message our research, there appears to be a positive correlation between pre-money valuation and the final amount of funds raised. Additionally, median household income can serve as a proxy for pre-money valuation. By scraping external data on median household income for each state from 2010 to 2021, we can further explore this relationship. By visualizing and comparing the median household income data with our previous map of 'Funding Raised by State,' we can investigate whether the observed relationship persists. This comparison may provide further evidence of the potential positive correlation between pre-money valuation and the amount of funding raised.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot a scatter plot with a regression line
plt.figure(figsize=(10, 6))
sns.regplot(x='average_income_2010_2013', y='raised_amount_usd', data=df, scatter_kws={'alpha':0.5})
plt.xlabel('Average Web Income (2010-2013)')
plt.ylabel('Raised Amount (USD)')
plt.title('Correlation between Raised Amount and Average Web Income')
plt.show()

# Print the correlation coefficient
correlation = df['average_income_2010_2013'].corr(df['raised_amount_usd'])
print(f"Correlation coefficient: {correlation}")
# Out:
# Correlation coefficient: 0.11710020899302392

# %% [markdown]
# The scatter plot visualizes the correlation between the **'Raised Amount (USD)'** and **'Average Web Income (2010-2013)'**. On the x-axis is the average web income over four years, and on the y-axis is the amount of funds raised. The upward trend suggested by the plotted points and the regression line indicates that states with higher average web incomes tend to report higher fundraising amounts. However, the broad confidence interval implies substantial uncertainty in this trend.
#
# Despite a correlation coefficient of around 0.117, which indicates a positive correlation, the relationship between the two variables is weak. This weak correlation indicates that factors other than average web income could be influential in fundraising outcomes. It suggests that while there might be a general trend for states with higher incomes to have higher raised amounts, the relationship is not deterministic, and predicting fundraising success based solely on average income would be unreliable. Thus, additional visualizations are necessary for a more comprehensive understanding of the dataset.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
df = pd.read_csv('/Users/project-one-code-yianxiong/ECO225Project/Data/dataset_project_3.csv', low_memory=False)

# Calculate the average income for the years 2010-2013 for each state
df['average_income_2010_2013'] = df[['web_income_2013', 'web_income_2012', 'web_income_2011', 'web_income_2010']].mean(axis=1)

# Group by state and calculate the average of the average incomes
average_income = df.groupby('web_state_name_income')['average_income_2010_2013'].mean().reset_index()

# Create a mapping of full state names to their two-letter codes
state_mapping = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA',
    'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA',
    'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA',
    'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD',
    'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO',
    'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ',
    'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH',
    'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC',
    'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT',
    'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'
}

# Map the full state names to their two-letter codes
average_income['state_code'] = average_income['web_state_name_income'].map(state_mapping)

# Setting the path to the shapefile
SHAPEFILE = '/Users/project-one-code-yianxiong/ECO225Project/Data/cb_2018_us_state_20m.shp'

# Read the shapefile into a GeoDataFrame
gdf = gpd.read_file(SHAPEFILE)

# Filter out Alaska, Hawaii, and minor islands
gdf = gdf[~gdf['STUSPS'].isin(['AK', 'HI', 'PR', 'VI', 'MP', 'GU', 'AS'])]

# Merge the average income data with the GeoDataFrame
merged_gdf = gdf.merge(average_income, left_on='STUSPS', right_on='state_code', how='left')

# Plotting the heatmap
fig, ax = plt.subplots(1, 1, figsize=(25, 15))
merged_gdf.plot(column='average_income_2010_2013', ax=ax, legend=True, cmap='coolwarm', edgecolor='black')

# Add state initials at the centroid of each state
for idx, row in merged_gdf.iterrows():
    ax.annotate(text=row['STUSPS'], xy=(row['geometry'].centroid.x, row['geometry'].centroid.y), ha='center', fontsize=8)

plt.title('Average Income in Dollars by State for 2010-2013 (Mainland US)')
plt.show()

# %% [markdown]
# Considering the dataset only extends to 2013, it's insightful to look at a heatmap of the average median household income from 2010 to 2013. The heatmap may reveal economic patterns across the U.S., highlighting areas like California and New York with elevated income levels, and Washington D.C., which stands out with the highest averages. This information is crucial, as it may hint at a supportive environment for startup valuations and investments, especially in regions with higher incomes, mirroring the trends observed in pre-money valuation and funding figures. Thus, such visualizations complement our research, suggesting that areas with higher average incomes may also be nurturing grounds for startups, affirming the interconnected nature of household income, startup valuations, and investment activities.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
df = pd.read_csv('/Users/project-one-code-yianxiong/ECO225Project/Data/dataset_project_3.csv', low_memory=False)

# Calculate the average income for the years 2021-2014 for each state
df['average_income_2021_2014'] = df[['web_income_2021', 'web_income_2019', 'web_income_2018', 'web_income_2017','web_income_2016', 'web_income_2015', 'web_income_2014']].mean(axis=1)

# Group by state and calculate the average of the average incomes
average_income = df.groupby('web_state_name_income')['average_income_2021_2014'].mean().reset_index()

# Create a mapping of full state names to their two-letter codes
state_mapping = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA',
    'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA',
    'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA',
    'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD',
    'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO',
    'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ',
    'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH',
    'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC',
    'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT',
    'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'
}

# Map the full state names to their two-letter codes
average_income['state_code'] = average_income['web_state_name_income'].map(state_mapping)

# Setting the path to the shapefile
SHAPEFILE = '/Users/project-one-code-yianxiong/ECO225Project/Data/cb_2018_us_state_20m.shp'

# Read the shapefile into a GeoDataFrame
gdf = gpd.read_file(SHAPEFILE)

# Filter out Alaska, Hawaii, and minor islands
gdf = gdf[~gdf['STUSPS'].isin(['AK', 'HI', 'PR', 'VI', 'MP', 'GU', 'AS'])]

# Merge the average income data with the GeoDataFrame
merged_gdf = gdf.merge(average_income, left_on='STUSPS', right_on='state_code', how='left')

# Plotting the heatmap
fig, ax = plt.subplots(1, 1, figsize=(25, 15))
merged_gdf.plot(column='average_income_2021_2014', ax=ax, legend=True, cmap='coolwarm', edgecolor='black')

# Add state initials at the centroid of each state
for idx, row in merged_gdf.iterrows():
    ax.annotate(text=row['STUSPS'], xy=(row['geometry'].centroid.x, row['geometry'].centroid.y), ha='center', fontsize=8)

plt.title('Average Income in Dollars by State for 2021-2014 (Mainland US)')
plt.show()

# %% [markdown]
# The median household income heatmap from 2021 to 2014 suggests a progression in economic prosperity for states like California and New York, complementing the findings related to fundraising activity highlighted in section 2.2 of our research. Although variations exist across the country—potentially influenced by the original dataset's scope—the ascending income trends in these key states reinforce our theory. The income growth could be indicative of an ecosystem ripe for startup investment, where a wealthier population may have a greater capacity to invest, thus possibly elevating both the pre-money valuation and the amounts raised. This correlation, while indirect, could lend credence to our research's primary assertion that pre-money valuation is positively associated with fundraising success.

# %% [markdown]
# ## 3.6 Adding a New Dataset

# %% [markdown]
# **Introduction to the New Data**
# The additional dataset, "US Startup Companies Over Time (Time Series)" (Kaggle, 2022), will enrich our original dataset with valuable information about startup companies in the US since 2008. This dataset includes details such as company name, location, team size, number of founders, and other relevant information. It introduces several potential independent variables for our study, including:
#
# - **'founded'**: The year the company was established.
# - **'team_size'**: The size of the company's team.
# - **'no_founders'**: The number of co-founders of the company.
# - **'no_company_socials'**: The count of social media profiles linked to the company.
# - **'no_tags'**: The number of tags or categories associated with the company.
#
# By incorporating these new variables into our original dataset, we can deepen our investigation into the relationship between pre-money valuation and the amount of funding raised, as suggested by our main message. Additionally, we can explore the influence of other factors on the success of startup fundraising, broadening the scope of our research.

# %% [markdown]
# **Merging the New Data to Original Dataset**

# %%
import pandas as pd

# Load the datasets
dataset_project_3 = pd.read_csv('/Users/project-one-code-yianxiong/ECO225Project/Data/dataset_project_3.csv', low_memory=False)
added_data = pd.read_csv('/Users/project-one-code-yianxiong/ECO225Project/Data/ycombinator_all.csv', low_memory=False)

# Concatenate the datasets horizontally
dataset_project_3_new = pd.concat([dataset_project_3, added_data], axis=1)

# Save the merged dataset to a new CSV file
dataset_project_3_new.to_csv('dataset_project_3_new.csv', index=False)

# %% [markdown]
# **Visualizing the New Dataset**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('dataset_project_3_new.csv', low_memory=False)

# Drop rows with missing values in 'no_founders'
df.dropna(subset=['no_founders'], inplace=True)

# Convert 'no_founders' to integers
df['no_founders'] = df['no_founders'].astype(int)

# Plotting the distribution of 'no_founders'
plt.figure(figsize=(10, 6))
sns.histplot(df['no_founders'], bins=range(1, df['no_founders'].max() + 1), color='blue')
plt.title('Distribution of Number of Founders')
plt.xlabel('Number of Founders')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The histogram above reveals a tendency for startup companies to have two founders, which is the most common configuration. This pattern suggests that startups prefer a collaborative foundation where responsibilities and resources can be shared. The prevalence of two-founder teams might be indicative of a strategy to combine diverse skills, networks, and financial resources, potentially leading to a more favorable pre-money valuation. Single-founder ventures are the next most frequent, which could be indicative of strong individual vision or a desire for greater control. The decreasing frequency as the number of founders increases beyond two could reflect the added complexity and coordination efforts required in larger founding teams. This information could serve as an essential consideration in venture capital dynamics, as the composition of the founding team can be a critical factor in investment decisions and pre-money valuation assessments.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('dataset_project_3_new.csv', low_memory=False)

# Drop rows with missing values in 'team_size' and 'raised_amount_usd'
df.dropna(subset=['team_size', 'raised_amount_usd'], inplace=True)

# Convert 'team_size' to integers if it's not already
df['team_size'] = df['team_size'].astype(int)

# Convert 'raised_amount_usd' to numeric, coercing errors to NaN and then dropping them
df['raised_amount_usd'] = pd.to_numeric(df['raised_amount_usd'], errors='coerce')
df.dropna(subset=['raised_amount_usd'], inplace=True)

# Remove outliers based on IQR for 'raised_amount_usd'
Q1 = df['raised_amount_usd'].quantile(0.25)
Q3 = df['raised_amount_usd'].quantile(0.75)
IQR = Q3 - Q1
# Adjust the 1.5 * IQR criteria if necessary
df = df[(df['raised_amount_usd'] >= (Q1 - 1.5 * IQR)) & (df['raised_amount_usd'] <= (Q3 + 1.5 * IQR))]

# Remove outliers based on IQR for 'team_size'
Q1 = df['team_size'].quantile(0.25)
Q3 = df['team_size'].quantile(0.75)
IQR = Q3 - Q1
df = df[(df['team_size'] >= (Q1 - 1.5 * IQR)) & (df['team_size'] <= (Q3 + 1.5 * IQR))]

# Plotting the correlation between 'raised_amount_usd' and 'team_size'
plt.figure(figsize=(10, 6))
sns.regplot(x='team_size', y='raised_amount_usd', data=df, scatter_kws={'alpha':0.1})

# Add a title and labels
plt.title('Correlation between Raised Amount (USD) and Team Size (Without Outliers)')
plt.xlabel('Team Size')
plt.ylabel('Raised Amount (USD)')

# Display the plot
plt.show()

# Print the correlation coefficient
correlation = df['team_size'].corr(df['raised_amount_usd'])
print(f"Correlation coefficient: {correlation}")
# Out:
# Correlation coefficient: 0.05471448694401086

# %% [markdown]
# The scatter plot presented showcases the correlation between the amount of funding raised, measured in USD, and the size of the company's team. On the horizontal axis, we have the team size, whereas the vertical axis quantifies the raised amount. A discernible upward trend suggested by the regression line hints at a positive correlation: companies with larger teams often raise larger sums of money. This trend, albeit mild, is visually reinforced by the linear trajectory of the line. The plot, however, reveals a concentration of data points at the smaller end of the scale, indicating that a majority of the companies have fewer team members and lower funding amounts.
#
# The correlation coefficient, stated as roughly 0.0547 beneath the plot, confirms the presence of a positive relationship between the two variables, yet emphasizes its weakness. Such a weak correlation suggests that the size of a team is not necessarily a reliable indicator of fundraising capability. The expansive confidence interval around the regression line further signifies considerable uncertainty in this estimated relationship, particularly as team size grows.
#
# Notably, some data points representing larger teams do not align with correspondingly substantial funding amounts. This observation implies that additional factors, beyond team size, are likely influential in determining the funding success of a company. Given this insight, our subsequent analysis will explore the relationships between various variables through Ordinary Least Squares (OLS) regressions to better understand the dynamics at play in startup funding.

# %% [markdown]
# ## 4.1 OLS Regression

# %% [markdown]
# In the initial project, the dependent variable Y is the amount of funds raised, focusing on how various factors influence startup fundraising success. Based on the preliminary data analysis, the relationship between Y and X (variables such as pre-money valuation) seems to be nonlinear. Economic theories such as the Law of Diminishing Returns suggest that after reaching a certain investment threshold, additional funding does not proportionally increase fundraising outcomes, supporting a nonlinear relationship. Additionally, the variability in how startups leverage different levels of investment points to complex dynamics that simple linear models may not capture.
#
# For the initial four regression analyses, the independent variables chosen from the original dataset include 'pre_money_valuation', 'participants', 'funding_round_type', and 'fund_raised_amount'. These variables were selected to explore their direct impact on the fundraising outcomes based on their prominence in venture capital dynamics. The subsequent four regression analyses utilize variables such as 'team_size', 'no_founders', 'no_company_socials', and 'no_tags' sourced from the additional dataset. These variables are intended to examine the influence of operational and social engagement factors on fundraising effectiveness, providing a broader perspective on the determinants of startup success.
#
# The preferred regression specification would be a model that includes interactions between key variables (such as pre-money valuation) and controls for potential confounders like market conditions and economic cycles. This model is preferred because it can reveal the combined effects of multiple factors on fundraising success, providing a deeper understanding of how these variables interplay in the venture capital context.

# %%
! pip install stargazer
from stargazer.stargazer import Stargazer
from IPython.core.display import HTML
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import statsmodels.api as sm
from statsmodels.iolib.summary2 import summary_col
from linearmodels.iv import IV2SLS
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv('dataset_project_3_new.csv', low_memory=False)
df1["fund_raised_amount1"] = 0
for i in range(df1.shape[0]):
    if df1["fund_raised_amount"][i] == 0:
        df1["fund_raised_amount1"][i] = df1["fund_raised_amount"][i]+ 0.001
    else:
        df1["fund_raised_amount1"][i] = df1["fund_raised_amount"][i]

# %%
df1["funding_round_type"].value_counts()
# Out:
# funding_round_type
# venture           15342
# angel             13163
# series-a           9873
# series-b           4892
# series-c+          4216
# other              4201
# private-equity     1043
# crowdfunding        111
# post-ipo             87
# Name: count, dtype: int64

# %%
df1["funding_round_type1"] = ""
for i in range(df1.shape[0]):
    if df1["funding_round_type"][i] in ["other", "private-equity", "post-ipo", "crowdfunding"]:
        df1["funding_round_type1"][i] = "other"
    else:
        df1["funding_round_type1"][i] = df1["funding_round_type"][i]
df1["venture"] = 0
df1["angel"] = 0
df1["series-a"] = 0
df1["series-b"] = 0
df1["series-c+"] = 0
df1["other"] = 0
for i in range(df1.shape[0]):
    if df1["funding_round_type1"][i] == "venture":
        df1["venture"][i] = 1
    if df1["funding_round_type1"][i] == "angel":
        df1["angel"][i] = 1
    if df1["funding_round_type1"][i] == "series-a":
        df1["series-a"][i] = 1
    if df1["funding_round_type1"][i] == "series-b":
        df1["series-b"][i] = 1
    if df1["funding_round_type1"][i] == "series-c+":
        df1["series-c+"][i] = 1
    if df1["funding_round_type1"][i] == "other":
        df1["other"][i] = 1

# %%
df1['const'] = 1
df1['log_fund_raised_amount'] = np.log(df1['fund_raised_amount1'])

# %% [markdown]
# For the initial regression analysis, we will focus solely on the categorical independent variable 'funding_round_type' and its associated dummy variables. This first regression serves as a foundation for the subsequent seven analyses. We will use the 'venture' category as our reference group because it contains the majority of observations. To simplify the analysis, we will combine less frequent categories such as 'private-equity', 'crowdfunding', and 'post-ipo' into the existing 'other' group. Consequently, we will break down the 'funding_round_type' into six distinct dummy variables to construct our initial regression model. This approach allows us to assess the impact of different funding types on the dependent variable while maintaining a clear and manageable model structure.

# %% [markdown]
# ### Regression 1

# %%
reg1 = sm.OLS(endog=df1['raised_amount_usd'], exog=df1[['const', 'angel', 'series-a', 'series-b', 'series-c+', 'other']], missing = 'drop').fit()
stargazer = Stargazer([reg1])
stargazer.custom_columns(["raised_amount_usd"],[1])
HTML(stargazer.render_html())
# Out:
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable: raised_amount_usd</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">raised_amount_usd</td></tr><tr><td style="text-align:left"></td><td>(1)</td></tr>
# <tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">angel</td><td>-7854364.006<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(495726.110)</td></tr>
# <tr><td style="text-align:left">const</td><td>8159983.345<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(336867.188)</td></tr>
# <tr><td style="text-align:left">other</td><td>8053239.835<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(658330.551)</td></tr>
# <tr><td style="text-align:left">series-a</td><td>-2245925.764<sup>***</sup></td></tr>
# ...

# %% [markdown]
# The first regression analysis is examining the impact of **funding round types** on the amount of capital raised, we observe that startups in angel funding rounds typically raise about \\$7.85 million less compared to those in the baseline venture rounds, which average a raise of approximately $81.60 million. Conversely, those startups that fall into the 'other' category of funding types exceed venture rounds by about \\$80.53 million. Furthermore, startups in Series A rounds tend to raise \\$22.46 million less than venture rounds, while Series B rounds show an increase, with startups raising \\$31.85 million more. Notably, companies in Series C or higher rounds have a pronounced increase in raised funds, averaging \\$130.01 million more than the baseline venture rounds.
#
# The R-squared value of 0.021 indicates that only 2.1% of the variability in the amount raised by startups is explained by the funding round types in this model. This suggests that while there are statistically significant differences between funding rounds, they do not account for most of the variation in the amount raised, pointing to other factors not included in this model that significantly influence fundraising outcomes. The F statistic is significant, suggesting that the model is statistically significant and that there is a relationship between the type of funding round and the amount raised. However, the low R-squared value indicates a need for caution in interpreting the results, as other unaccounted variables may also play a significant role in determining fundraising amounts. As the first model, it does not imply causation but rather an association between the type of funding round and fundraising outcomes.
#
# The first regression explores the impact of different funding rounds on startup fundraising, providing insights into how maturity and perceived risk influence investment amounts. Angel rounds, representing early-stage funding, typically see lower amounts raised due to higher uncertainty. In contrast, Series B and C+ rounds involve more established startups, thus attracting more capital due to their proven market potential and lower risk. The 'other' category may capture diverse and non-standard funding strategies, possibly leading to higher fundraising amounts. Regression one helps in understanding the variation in venture capital behavior and how different funding stages correlate with fundraising success.

# %% [markdown]
# ### Regression 2

# %%
reg2 = sm.OLS(endog=df1['raised_amount_usd'], exog=df1[['const', 'pre_money_valuation_usd',
                                                       'angel', 'series-a', 'series-b', 'series-c+', 'other']], missing = 'drop').fit()
stargazer = Stargazer([reg2])
stargazer.custom_columns(["raised_amount_usd"],[1])
HTML(stargazer.render_html())
# Out:
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable: raised_amount_usd</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">raised_amount_usd</td></tr><tr><td style="text-align:left"></td><td>(1)</td></tr>
# <tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">angel</td><td>-7854233.311<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(495599.444)</td></tr>
# <tr><td style="text-align:left">const</td><td>8159839.568<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(336781.114)</td></tr>
# <tr><td style="text-align:left">other</td><td>8053383.612<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(658162.336)</td></tr>
# <tr><td style="text-align:left">pre_money_valuation_usd</td><td>0.015<sup>***</sup></td></tr>
# ...

# %% [markdown]
# Regression 2 introduces the variable **'pre_money_valuation_usd'** alongside the categorical variables for funding rounds. Each unit increase in pre-money valuation is associated with an increase of \\$0.015 million in the raised amount, holding other variables constant. This result is highly significant, indicating that higher pre-money valuations are strongly correlated with larger amounts of capital raised.
#
# For the categorical variables, the negative coefficient for 'angel' indicates that startups in angel rounds raise approximately \\$7.85 million less than the baseline 'venture' round. The 'other' category shows startups in these rounds raise approximately \\$80.54 million more than those in 'venture' rounds. 'Series-a' rounds raise roughly \\$22.46 million less, while 'Series-b' and 'Series-c+' rounds are associated with significantly higher amounts raised compared to 'venture' rounds, by about \\$31.81 million and \\$129.51 million more, respectively.
#
# The R-squared value, sitting at 0.022, tells us that when combined with the types of funding rounds, the pre-money valuation explains 2.2% of the variation in fundraising amounts. Despite the low R-squared value indicating a limited explanatory power, the significant F statistic reinforces that the variables included are collectively relevant for the model. This suggests that while funding round types and pre-money valuation are associated with fundraising outcomes, a substantial portion of the variance remains unexplained by these factors alone, highlighting the complex nature of startup financing and the potential influence of other variables not captured in this regression.
#
# Economically, regression 2 is designed to discern not just the categorical impact of the type of funding round, but also to quantify the effect of valuation before fundraising. It clarifies the financial expectations that venture capitalists might have in correlation with a startup's valuation. This regression holds critical value as it begins to unpack the dynamic interplay between perceived startup value prior to funding and the concrete financial outcomes of funding rounds. The economic reasoning for running regression 2 is to investigate if pre-money valuations serve as a signal to investors regarding the future potential and current stability of a startup, which influencing their willingness to invest and the amount of capital they are prepared to commit.

# %% [markdown]
# ### Regression 3

# %%
reg3 = sm.OLS(endog=df1['raised_amount_usd'], exog=df1[['const', 'pre_money_valuation_usd', 'participants',
                                                       'angel', 'series-a', 'series-b', 'series-c+', 'other']], missing = 'drop').fit()
stargazer = Stargazer([reg3])
stargazer.custom_columns(["raised_amount_usd"],[1])
HTML(stargazer.render_html())
# Out:
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable: raised_amount_usd</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">raised_amount_usd</td></tr><tr><td style="text-align:left"></td><td>(1)</td></tr>
# <tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">angel</td><td>-7953106.490<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(495059.205)</td></tr>
# <tr><td style="text-align:left">const</td><td>6967444.853<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(351949.382)</td></tr>
# <tr><td style="text-align:left">other</td><td>8767210.939<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(660263.915)</td></tr>
# <tr><td style="text-align:left">participants</td><td>1088780.820<sup>***</sup></td></tr>
# ...

# %% [markdown]
# Regression 3 introduces **'participants'** as an additional independent variable alongside the funding round types and pre-money valuation. The model indicates that startups in angel rounds raise significantly less, approximately \\$7.95 million less than the baseline category, holding all else constant. Startups in the baseline group 'venture' raising an average of approximately \\$69.67 million. The 'other' category raises about \\$87.67 million more compared to the 'venture' category. The number of participants has a positive coefficient, indicating that each additional participant is associated with an increase of about \\$108,878 in the raised amount, showing the positive impact of having more investors on the fundraising amount.
#
# With each unit increase in pre-money valuation (in USD) leading to an increase of \\$0.015 million in the raised amount. 'Series-a' rounds are associated with a decrease of approximately \\$32.85 million compared to 'venture' rounds, whereas 'series-b' rounds show an increase of about \\$16.71 million. 'Series-c+' rounds are linked with an even more significant increase, with startups raising around \\$105.98 million more than in 'venture' rounds.
#
# The addition of the 'participants' variable slightly improves the model, with an R-squared value of 0.024. This modest increase in explanatory power suggests that the number of investors participating in a round does have a bearing on the amount raised, yet it still leaves a large proportion of the variation unaccounted for. Similar to regression 2, the F statistic is significant, providing evidence that the model's predictors collectively impact the fundraising amounts. Despite this, the low R-squared values across both regressions emphasize the multifaceted nature of startup fundraising and underscore the need for further investigation into additional factors that could better explain the success in raising funds. Both regression 2 and regression 3 point to a complex interplay of variables and underscore the importance of looking beyond the examined factors to fully understand the dynamics of venture capital financing.
#
# The economic reasoning for conducting regression 3 is to explore the impact of investor interest, reflected by the number of participants, on fundraising outcomes. By quantifying the incremental effect of each additional participant, this regression assesses the collective influence of investor networks and the aggregation of capital contributions on the fundraising success of startups, further refining our understanding of factors that contribute to effective fundraising.

# %% [markdown]
# ### Regression 4

# %%
reg4 = sm.OLS(endog=df1['raised_amount_usd'], exog=df1[['const', 'pre_money_valuation_usd', 'participants', 'log_fund_raised_amount',
                                                       'angel', 'series-a', 'series-b', 'series-c+', 'other']], missing = 'drop').fit()
stargazer = Stargazer([reg4])
stargazer.custom_columns(["raised_amount_usd"],[1])
HTML(stargazer.render_html())
# Out:
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable: raised_amount_usd</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">raised_amount_usd</td></tr><tr><td style="text-align:left"></td><td>(1)</td></tr>
# <tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">angel</td><td>-23583921.063<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(7297464.953)</td></tr>
# <tr><td style="text-align:left">const</td><td>22672200.682<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(7321934.413)</td></tr>
# <tr><td style="text-align:left">log_fund_raised_amount</td><td>13813.166<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(54590.285)</td></tr>
# <tr><td style="text-align:left">other</td><td>-14776484.920<sup>*</sup></td></tr>
# ...

# %% [markdown]
# In regression 4, we introduce the transformed variable **'log_fund_raised_amount'** to capture the impact of the fund-raised amount on the raised_amount_usd in a non-linear fashion, alongside the pre-money valuation and various funding rounds as predictors. The findings indicate a significant positive association between the log of fund-raised amounts and the amount raised, highlighting the proportional change in fundraising success with respect to the capital available from venture capital funds. The negative coefficient for 'angel' suggests that angel rounds are associated with raising significantly less capital compared to the baseline venture category, while 'series-a' rounds also show a decrease in raised amounts. Conversely, 'series-b' and 'series-c+' rounds indicate higher fundraising outcomes.
#
# This model demonstrates a higher R-squared value of 0.204, indicating that these variables explain approximately 20.4% of the variance in fundraising amounts, marking an improvement from previous models and suggesting that log transformations and the inclusion of pre-money valuation provide a more comprehensive understanding of fundraising dynamics. The significant F statistic reinforce the collective impact of these variables on fundraising outcomes.
#
# The economic rationale for running regression 4 centers on the hypothesis that the relationship between funds available and capital raised by startups is multiplicative rather than additive, aligning with economic principles that consider the logarithmic scale of investments and returns. This regression also aims to test whether pre-money valuations significantly influence investor decisions and capital allocation, as higher initial valuations may signal greater growth potential and stability, hence attracting more substantial investments.

# %% [markdown]
# ### Regression 5

# %%
reg5 = sm.OLS(endog=df1['raised_amount_usd'], exog=df1[['const', 'pre_money_valuation_usd', 'participants', 
                                                        'log_fund_raised_amount', 'team_size',
                                                       'angel', 'series-a', 'series-b', 'series-c+', 'other']], missing = 'drop').fit()
stargazer = Stargazer([reg5])
stargazer.custom_columns(["raised_amount_usd"],[1])
HTML(stargazer.render_html())
# Out:
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable: raised_amount_usd</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">raised_amount_usd</td></tr><tr><td style="text-align:left"></td><td>(1)</td></tr>
# <tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">angel</td><td>-10454132.438<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(7191261.253)</td></tr>
# <tr><td style="text-align:left">const</td><td>10288819.725<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(7224907.450)</td></tr>
# <tr><td style="text-align:left">log_fund_raised_amount</td><td>25703.380<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(61436.340)</td></tr>
# <tr><td style="text-align:left">other</td><td>-9016824.943<sup></sup></td></tr>
# ...

# %% [markdown]
# Regression 5 adds **'team_size'** to the model, examining its influence on the dependent variable 'raised_amount_usd' while controlling for other factors. The negative coefficient for 'angel' indicates that, compared to the baseline category, startups in angel rounds raise significantly less capital. The positive coefficient for 'log_fund_raised_amount' implies that as the log of fund-raised amounts increases, so does the capital raised by startups, suggesting a log-linear relationship. Startups in the 'other' category seem to raise less capital compared to the baseline 'venture' category. Each additional participant is associated with an increase in the amount raised, highlighting the positive impact of investor engagement.
#
# However, the coefficient for 'team_size' is negative, which is counterintuitive as we might expect larger teams to have more resources and networks to raise more capital. It could be that larger teams dilute equity or signal to investors that the startup is less lean and potentially less efficient. This model has a higher R-squared value of 0.265, suggesting that approximately 26.5% of the variance in fundraising amounts can be explained by the included predictors. This model marks a substantial improvement from previous models in terms of explanatory power.
#
# The economic reasoning behind regression 5 focuses on the potential impact of internal resources, as represented by team size, on fundraising success. The model aims to test the hypothesis that a startup's internal capabilities, including its human resources, are significant in attracting investment. It evaluates whether larger teams correlate with greater fundraising outcomes, which may reflect a startup's operational capacity and ability to execute its business plan effectively. The regression allows us to parse out the contribution of a startup's team dynamics alongside external factors such as investor interest and pre-money valuation.

# %% [markdown]
# ### Regression 6

# %%
reg6 = sm.OLS(endog=df1['raised_amount_usd'], exog=df1[['const', 'pre_money_valuation_usd', 'participants', 
                                                        'log_fund_raised_amount', 'team_size','no_founders',
                                                       'angel', 'series-a', 'series-b', 'series-c+', 'other']], missing = 'drop').fit()
stargazer = Stargazer([reg6])
stargazer.custom_columns(["raised_amount_usd"],[1])
HTML(stargazer.render_html())
# Out:
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable: raised_amount_usd</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">raised_amount_usd</td></tr><tr><td style="text-align:left"></td><td>(1)</td></tr>
# <tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">angel</td><td>-10314526.352<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(7192064.975)</td></tr>
# <tr><td style="text-align:left">const</td><td>11470310.936<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(7310723.627)</td></tr>
# <tr><td style="text-align:left">log_fund_raised_amount</td><td>22683.868<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(61499.406)</td></tr>
# <tr><td style="text-align:left">no_founders</td><td>-641383.253<sup></sup></td></tr>
# ...

# %% [markdown]
# Regression 6 introduces **'no_founders'** as an independent variable alongside previously included factors such as 'participants' and 'pre_money_valuation_usd'. The negative coefficient for 'no_founders' is quite notable; it suggests that each additional founder is associated with a decrease of approximately \$641,383 in the amount raised. This could imply that startups with more founders might face difficulties in raising funds, potentially due to dilution of equity, differing visions, or operational complexities that come with a larger founding team. The coefficients for 'angel', 'series-a', 'series-b', and 'series-c+' round types follow the patterns observed in prior regressions, indicating how different funding rounds compare to the baseline 'venture' category in terms of raised capital. The positive coefficient for 'pre_money_valuation_usd' remains consistent with earlier models, underscoring the importance of valuation in attracting capital.
#
# With an R-squared value of 0.266, this model explains about 26.6% of the variability in the dependent variable, signifying a moderate fit. The inclusion of 'no_founders' does not substantially change the explanatory power of the model compared to regression 5, but it adds a new dimension to understanding how internal dynamics might influence fundraising success. The significant F statistic confirms the overall validity of the regression.
#
# The economic reasoning for conducting regression 6 is to delve into the influence of the size of the founding team on the ability to raise funds. Economically, it is crucial to consider the impact of having multiple founders on investor confidence, decision-making processes, and the strategic direction of a startup. This regression allows us to explore whether a larger number of founders could be perceived as a strength, offering a diverse skill set and broader network, or a liability, possibly leading to conflicts or diluted ownership, which may affect fundraising.

# %% [markdown]
# ### Regression 7

# %%
reg7 = sm.OLS(endog=df1['raised_amount_usd'], exog=df1[['const', 'pre_money_valuation_usd', 'participants', 'log_fund_raised_amount', 
                                                        'team_size','no_founders','no_company_socials','angel', 'series-a', 'series-b',
                                                        'series-c+', 'other']], missing = 'drop').fit()
stargazer = Stargazer([reg7])
stargazer.custom_columns(["raised_amount_usd"],[1])
HTML(stargazer.render_html())
# Out:
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable: raised_amount_usd</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">raised_amount_usd</td></tr><tr><td style="text-align:left"></td><td>(1)</td></tr>
# <tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">angel</td><td>-10683765.717<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(7191687.082)</td></tr>
# <tr><td style="text-align:left">const</td><td>13042652.427<sup>*</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(7380579.915)</td></tr>
# <tr><td style="text-align:left">log_fund_raised_amount</td><td>23954.871<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(61466.105)</td></tr>
# <tr><td style="text-align:left">no_company_socials</td><td>-623861.676<sup></sup></td></tr>
# ...

# %% [markdown]
# In regression 7, we include **'no_company_socials'** as a new independent variable, which interestingly has a negative coefficient, suggesting that each additional social media account is associated with a decrease of approximately \$623,861 in the amount raised. This could point to a scenario where excessive social media presence may not translate into successful fundraising, possibly indicating an overemphasis on marketing over substantive business development. All other coefficients, including 'pre_money_valuation_usd' with its consistent positive impact and 'participants' indicating the positive effect of increased investor engagement, remain in line with the trends observed in previous models.
#
# The R-squared value of 0.268 shows a slight improvement from the previous model, suggesting that the new variable 'no_company_socials' adds some explanatory power to the model. Still, with the vast majority of the variation in fundraising amounts unexplained, it highlights the complexity of fundraising dynamics and the potential influence of unobserved factors.
#
# The economic reasoning for conducting regression 7 is to assess the impact of a startup's social media footprint on its ability to attract funding. With the increasing relevance of digital presence in company valuation and marketing, it becomes essential to understand how this aspect correlates with actual fundraising outcomes. The negative coefficient for 'no_company_socials' prompts a reconsideration of the effectiveness of social media strategies in the context of venture capital and fundraising. It suggests the need for startups to balance their online presence with other aspects of business development that more directly contribute to investment attractiveness.

# %% [markdown]
# ### Regression 8

# %%
reg8 = sm.OLS(endog=df1['raised_amount_usd'], exog=df1[['const', 'pre_money_valuation_usd', 'participants', 'log_fund_raised_amount', 
                                                        'team_size','no_founders','no_company_socials', 'no_tags',
                                                       'angel', 'series-a', 'series-b', 'series-c+', 'other']], missing = 'drop').fit()
stargazer = Stargazer([reg8])
stargazer.custom_columns(["raised_amount_usd"],[1])
HTML(stargazer.render_html())
# Out:
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable: raised_amount_usd</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">raised_amount_usd</td></tr><tr><td style="text-align:left"></td><td>(1)</td></tr>
# <tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">angel</td><td>-10752354.179<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(7195076.087)</td></tr>
# <tr><td style="text-align:left">const</td><td>13839686.623<sup>*</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(7509901.635)</td></tr>
# <tr><td style="text-align:left">log_fund_raised_amount</td><td>23572.164<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(61490.303)</td></tr>
# <tr><td style="text-align:left">no_company_socials</td><td>-617151.818<sup></sup></td></tr>
# ...

# %% [markdown]
# Interpreting regression 8, **'no_tags'** as an independent variable has been introduced, and its coefficient suggests a negative relationship with the dependent variable 'raised_amount_usd', indicating that an increase in the number of tags associated with a company corresponds to a decrease of approximately \$179,477 in the amount raised. This may imply that a broader scope of tagged interests or sectors doesn't necessarily correlate with fundraising success and could represent a lack of focus that is unattractive to investors.
#
# The 'angel' category continues to show a substantial negative coefficient, reiterating that angel rounds tend to secure less funding compared to the baseline 'venture' rounds. The positive coefficient for 'participants' remains consistent across regressions, emphasizing the positive impact of having a larger pool of investors on fundraising. 'Pre_money_valuation_usd' still shows its expected positive influence on the raised amount, reinforcing the importance of pre-funding valuation as a success predictor for fundraising.
#
# This regression, with an R-squared value of 0.268, is similar to previous models, indicating that while the included variables are significant, there remains a large proportion of unexplained variability in fundraising outcomes. The adjusted R-squared of 0.259 and the significant F statistic suggest that the model is generally reliable, but the inclusion of 'no_tags' has not dramatically increased the explanatory power of the model.
#
# The economic reasoning for running regression 8 is to explore how the breadth of a company's interests and sectors, as indicated by the number of tags, affects its fundraising outcomes. This regression aims to understand whether having a specific focus or a broader range of interests as reflected by tags influences investor decisions and fundraising success. The negative coefficient for 'no_tags' may suggest that investors prefer companies with a more focused approach, which can be seen as a clearer and possibly more reliable investment prospect.

# %% [markdown]
# ### Regression Comparison

# %%
stargazer = Stargazer([reg1, reg2, reg3, reg4, reg5, reg6, reg7, reg8]) 
stargazer.custom_columns(["raised_amount_usd"],[8]) 
HTML(stargazer.render_html())
# Out:
# <table style="text-align:center"><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="8"><em>Dependent variable: raised_amount_usd</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="8">raised_amount_usd</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td></tr>
# <tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">angel</td><td>-7854364.006<sup>***</sup></td><td>-7854233.311<sup>***</sup></td><td>-7953106.490<sup>***</sup></td><td>-23583921.063<sup>***</sup></td><td>-10454132.438<sup></sup></td><td>-10314526.352<sup></sup></td><td>-10683765.717<sup></sup></td><td>-10752354.179<sup></sup></td></tr>
# ...

# %% [markdown]
# All models consistently show that the pre-money valuation (pre_money_valuation_usd) has a positive effect on the raised amount, which supports the hypothesis that higher valuations before funding lead to higher fundraising success. The number of participants (participants) also shows a positive effect across all models, suggesting that having more investors is associated with a larger fundraising amount. At the same time, the type of funding round (angel, series-a, series-b, series-c+, other) impacts the raised amount significantly, with later stages like series-c+ generally associated with higher amounts raised. Finally in regressions 5 to 8, the team size (team_size) and the number of company social media accounts (no_company_socials) were added to the model. The number of tags (no_tags) and the number of founders (no_founders) are also considered in models 6 to 8.
#
# Based on the coefficients and p-values, all the variables included appear to be significant predictors of the raised amount. The best model would be the one with the highest explanatory power (highest R-squared and adjusted R-squared values) and the one where the predictors are significant and make sense from an economic standpoint.
#
# From the above statistics, the model of regression 7 has the highest R-squared and adjusted R-squared values, meaning it explains the most variability in the raised amount compared to the other models.

# %% [markdown]
# ## 4.2 Machine Learning

# %%
#!pip install -U scikit-learn scipy matplotlib
from sklearn import (linear_model, tree, metrics, pipeline, model_selection)
df_clean = df1.dropna(subset=['raised_amount_usd'])
reg7_x = df_clean[['pre_money_valuation_usd', 'participants', 'log_fund_raised_amount', 
                   'team_size','no_founders','no_company_socials','angel', 'series-a', 'series-b',
                   'series-c+', 'other']]
startup_tree = tree.DecisionTreeRegressor(max_depth=3).fit(reg7_x, df_clean['raised_amount_usd']) 
startup_fig = plt.figure(figsize=(15,15))
startup_fig = tree.plot_tree(startup_tree, feature_names=df1.columns, filled=True)

# %% [markdown]
# The objective function of our regression tree is to ascertain the optimal number of terminal nodes that minimize the sum of squared differences between the actual fundraising amounts and the predicted values for each unique segment of startups. This is done by averaging the fundraising outcomes of startups within each segment, penalized by a factor of the tree's complexity parameter multiplied by the number of terminal nodes. This approach essentially aims to achieve the lowest mean squared error, balancing model accuracy with complexity.
#
# In our context, the regularization parameter, typically denoted as α, modulates the balance between the tree's complexity and its fit to the training data. A higher value of α imposes a stiffer penalty for complexity, resulting in a more streamlined model with fewer branches, which mitigates the risk of overfitting and typically enhances the model's performance on unseen data. Conversely, a lower α value allows for a more intricate model that may fit the training data more closely but risks overfitting, which could degrade its performance on new data.

# %% [markdown]
# ## Conclusion and Future Work

# %% [markdown]
# In conclusion, our primary discovery is the affirmation of a positive association between pre-money valuations and fundraising outcomes. This alignment supports the economic theory that suggests higher pre-money valuations could signal market confidence and attract increased capital influx.
#
# Diving deeper into the venture capital ecosystem, our geographical analysis revealed that regions such as California and New York are not only focal points of higher pre-money valuations but also correspond to larger fundraising totals. This finding indicates that regional economic health and the propensity for venture capital activities are interlinked, with implications for policymakers and stakeholders in regional development.
#
# The research, however, does not stand without its limitations. The R-squared values across our regression models were modest, highlighting the presence of other influential factors not captured by our current model. It is apparent that variables beyond pre-money valuation which possibly including market trends, investor behavior, and startup intrinsic value would contribute significantly to fundraising success.
#
# In striving towards a publishable standard, the possible future work will seek to refine the current model and address these limitations. The addition of time-series data to account for market fluctuations, the inclusion of more granular geographical data to parse out regional economic factors, and the utilization of more sophisticated regression techniques such as quantile regressions or machine learning models are considered as methodological enhancements. These improvements, supported by a broader dataset, could yield a more comprehensive understanding of the venture capital landscape.
#
# Next steps could also involve a more extensive analysis of the startup ecosystem's structure, such as examining the role of founder expertise and network effects. Limitations such as potential biases in data reporting and the challenge of capturing the qualitative aspects of startup potential will be mitigated through the pursuit of more diverse data sources. The future work, therefore, will not only extend the current research but also aims to fill the gaps identified, thereby enhancing the robustness and applicability of the findings within the realm of economic sciences.

# %% [markdown]
# ## References

# %% [markdown]
# Cirtautas, J. (2013, December 11). Startup Investments. Www.kaggle.com; Crunchbase. https://www.kaggle.com/datasets/justinas/startup-investments/data?select=funds.csv
#
# Zider, B. (1998). How Venture Capital Works Harvard Business Review. http://mengwong.com/school/HarvardBusinessReview/how_venture_works.pdf
#
# Chen, J., & Ewens, M. (2021, September 1). Venture Capital and Startup Agglomeration. Social Science Research Network. https://papers.ssrn.com/sol3/papers.cfm?abstract_id=3918106
#
# Understanding Pre-Money vs. Post-Money Valuation. (2023, April 28). Varnum LLP. https://www.varnumlaw.com/insights/understanding-pre-money-vs-post-money-valuation/
#
# ‌Elvira, M. (2023, March 20). Why California is the Perfect Place for International EdTech Startups to Enter the US Market. https://www.linkedin.com/pulse/why-california-perfect-place-international-edtech-startups-elvira/
#
# Kenton, W. (2024, March 19). Bootstrapping Definition, Strategies, and Pros/Cons. Investopedia. https://www.investopedia.com/terms/b/bootstrapping.asp#:~:text=Bootstrapping%20a%20company%20occurs%20when,cash%20runway%20to%20become%20successful.
#
# Wikipedia contributors. (2024, February 26). List of U.S. states and territories by income. Wikipedia. https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_income
#
# US Startup companies over time (Timeseries). (2022, November 16). Kaggle. https://www.kaggle.com/datasets/thedevastator/empowering-the-next-wave-of-entrepreneurs/data
